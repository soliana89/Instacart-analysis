# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Importing Dataframes

# %%
#path= pathway to project folder
path = r"C:\Users\solza\Downloads\12-2022 Instacart Basket Analysis"

# %%
#updated dataframe orders_products_merged_update.pkl
ords_prods_merged= pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_update.pkl'))

# %%
ords_prods_merged.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0             0             0   2539329        1             1
# 1             1             1   2398795        1             2
# 2             2             2    473747        1             3
# 3             3             3   2254736        1             4
# 4             4             4    431534        1             5
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                   2                  8                     NaN         196
# 1                   3                  7                    15.0         196
# 2                   3                 12                    21.0         196
# 3                   4                  7                    29.0         196
# 4                   4                 15                    28.0         196
#
#    add_to_cart_order  ...  Unnamed: 0_y  product_name aisle_id  department_id  \
# ...

# %%
#remove _merge column, which was a check for full merge, and busiest day column, since we are interested in the busiest days of the week
ords_prods_merged= ords_prods_merged.drop(columns= ['busiest_day', '_merge'])

# %%
ords_prods_merged.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0             0             0   2539329        1             1
# 1             1             1   2398795        1             2
# 2             2             2    473747        1             3
# 3             3             3   2254736        1             4
# 4             4             4    431534        1             5
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                   2                  8                     NaN         196
# 1                   3                  7                    15.0         196
# 2                   3                 12                    21.0         196
# 3                   4                  7                    29.0         196
# 4                   4                 15                    28.0         196
#
#    add_to_cart_order  reordered  Unnamed: 0_y product_name  aisle_id  \
# ...

# %%
ords_prods_merged.shape
# Out:
# (32404859, 19)

# %% [markdown]
# # question 02

# %%
#aggregate mean of 'order_number' grouped by 'department_id'for the entire dataframe
ords_prods_merged.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     15.457838
# 2     17.277920
# 3     17.170395
# 4     17.811403
# 5     15.215751
# 6     16.439806
# 7     17.225802
# 8     15.340650
# 9     15.895474
# 10    20.197148
# 11    16.170638
# 12    15.887671
# 13    16.583536
# 14    16.773669
# 15    16.165037
# 16    17.665606
# 17    15.694469
# 18    19.310397
# 19    17.177343
# 20    16.473447
# 21    22.902379
# Name: order_number, dtype: float64

# %% [markdown]
# the mean for the complete dataframe is different from the first million entries.It gives a complete mean of all departments.
# therefore the average for each department differs by a small subamples.

# %% [markdown]
# # Q.4 Create a loyalty flag for existing customers

# %%
#split data into groups based on user_id, and tranform order_number to generate max orders for each user
ords_prods_merged['max_order']= ords_prods_merged.groupby(['user_id'])['order_number'].transform(np.max)

# %%
#check accuracy
pd.options.display.max_rows= None
ords_prods_merged.head(100)
# Out:
#     Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0              0             0   2539329        1             1
# 1              1             1   2398795        1             2
# 2              2             2    473747        1             3
# 3              3             3   2254736        1             4
# 4              4             4    431534        1             5
# 5              5             5   3367565        1             6
# 6              6             6    550135        1             7
# 7              7             7   3108588        1             8
# 8              8             8   2295261        1             9
# 9              9             9   2550362        1            10
# 10           144           144   2968173       15            15
# 11           146           146   1870022       15            17
# 12           147           147   1911383       15            18
# 13           150           150   2715276       15            21
# ...

# %%
#derive column conditions
ords_prods_merged.loc[ords_prods_merged['max_order']>40, 'loyalty_flag']= 'Loyal customer'

# %%
ords_prods_merged.loc[(ords_prods_merged['max_order']<=40) & (ords_prods_merged['max_order']>10), 'loyalty_flag']= 'Regular customer'

# %%
ords_prods_merged.loc[ords_prods_merged['max_order']<=10, 'loyalty_flag']= 'New customer'

# %%
#frequency of loyalty_flag
ords_prods_merged['loyalty_flag'].value_counts(dropna=False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
ords_prods_merged[['user_id', 'loyalty_flag', 'order_number']].head(20)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22
# 15       19      New customer             2
# 16       19      New customer             5
# 17       19      New customer             7
# 18       21  Regular customer            10
# 19       31  Regular customer            10

# %% [markdown]
# # Q.5 Does the price of products purchased by loyal customers differ from regular or new customers

# %%
ords_prods_merged.groupby('loyalty_flag').agg({'prices':['mean', 'min', 'max', 'sum']})
# Out:
#                      prices
#                        mean  min      max          sum
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0  106814042.2
# New customer      13.294670  1.0  99999.0   83011787.2
# Regular customer  12.495717  1.0  99999.0  198391693.2

# %% [markdown]
# Loyal customers on average spend the least amount of money on their products, whereas new customers spend the most amount of money on their purchases.¶

# %% [markdown]
# # Q.6 split data into groups based on user_id, and transform prices to generate average_price for each user

# %%
ords_prods_merged['average_price']= ords_prods_merged.groupby(['user_id'])['prices'].transform(np.mean)

# %%
#check accuracy
ords_prods_merged.head(60)
# Out:
#     Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0              0             0   2539329        1             1
# 1              1             1   2398795        1             2
# 2              2             2    473747        1             3
# 3              3             3   2254736        1             4
# 4              4             4    431534        1             5
# 5              5             5   3367565        1             6
# 6              6             6    550135        1             7
# 7              7             7   3108588        1             8
# 8              8             8   2295261        1             9
# 9              9             9   2550362        1            10
# 10           144           144   2968173       15            15
# 11           146           146   1870022       15            17
# 12           147           147   1911383       15            18
# 13           150           150   2715276       15            21
# ...

# %%
#derive column conditions
ords_prods_merged.loc[ords_prods_merged['average_price']<10, 'spending_flag']= 'Low spender'

# %%
ords_prods_merged.loc[ords_prods_merged['average_price']>=10, 'spending_flag']= 'High spender'

# %%
#frequency of spending_flag
ords_prods_merged['spending_flag'].value_counts(dropna= False)
# Out:
# Low spender     31770614
# High spender      634245
# Name: spending_flag, dtype: int64

# %%
ords_prods_merged[['user_id', 'spending_flag', 'loyalty_flag', 'order_number']].head(20)
# Out:
#     user_id spending_flag      loyalty_flag  order_number
# 0         1   Low spender      New customer             1
# 1         1   Low spender      New customer             2
# 2         1   Low spender      New customer             3
# 3         1   Low spender      New customer             4
# 4         1   Low spender      New customer             5
# 5         1   Low spender      New customer             6
# 6         1   Low spender      New customer             7
# 7         1   Low spender      New customer             8
# 8         1   Low spender      New customer             9
# 9         1   Low spender      New customer            10
# 10       15   Low spender  Regular customer            15
# 11       15   Low spender  Regular customer            17
# 12       15   Low spender  Regular customer            18
# 13       15   Low spender  Regular customer            21
# 14       15   Low spender  Regular customer            22
# ...

# %% [markdown]
# # Q.7 split data into groups based on user_ids, and transform days_since_prior_order to generate median_order_frequency

# %%
ords_prods_merged['median_order_frequency']= ords_prods_merged.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
#check accuracy
ords_prods_merged.head(60)
# Out:
#     Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0              0             0   2539329        1             1
# 1              1             1   2398795        1             2
# 2              2             2    473747        1             3
# 3              3             3   2254736        1             4
# 4              4             4    431534        1             5
# 5              5             5   3367565        1             6
# 6              6             6    550135        1             7
# 7              7             7   3108588        1             8
# 8              8             8   2295261        1             9
# 9              9             9   2550362        1            10
# 10           144           144   2968173       15            15
# 11           146           146   1870022       15            17
# 12           147           147   1911383       15            18
# 13           150           150   2715276       15            21
# ...

# %%
#derive column conditions
ords_prods_merged.loc[ords_prods_merged['median_order_frequency']>20, 'order_frequency_flag']= 'Non-frequent customer'

# %%
ords_prods_merged.loc[(ords_prods_merged['median_order_frequency']>10) & (ords_prods_merged['median_order_frequency']<=20), 'order_frequency_flag']= 'Regular customer'

# %%
ords_prods_merged.loc[ords_prods_merged['median_order_frequency']<=10, 'order_frequency_flag']= 'Frequent customer'

# %%
#frequency of order_frequency_flag
ords_prods_merged['order_frequency_flag'].value_counts(dropna= False)
# Out:
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# NaN                             5
# Name: order_frequency_flag, dtype: int64

# %%
ords_prods_merged[['user_id', 'loyalty_flag', 'spending_flag', 'order_frequency_flag']].head(60)
# Out:
#     user_id      loyalty_flag spending_flag   order_frequency_flag
# 0         1      New customer   Low spender  Non-frequent customer
# 1         1      New customer   Low spender  Non-frequent customer
# 2         1      New customer   Low spender  Non-frequent customer
# 3         1      New customer   Low spender  Non-frequent customer
# 4         1      New customer   Low spender  Non-frequent customer
# 5         1      New customer   Low spender  Non-frequent customer
# 6         1      New customer   Low spender  Non-frequent customer
# 7         1      New customer   Low spender  Non-frequent customer
# 8         1      New customer   Low spender  Non-frequent customer
# 9         1      New customer   Low spender  Non-frequent customer
# 10       15  Regular customer   Low spender      Frequent customer
# 11       15  Regular customer   Low spender      Frequent customer
# 12       15  Regular customer   Low spender      Frequent customer
# ...

# %% [markdown]
# # Export Data

# %%
ords_prods_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged_update(2).pkl'))
